# %% [markdown]
# # Automação de Sistemas e Processos com Python
#
# ### Desafio:
#
# Todos os dias, o nosso sistema atualiza as vendas do dia anterior.
# O seu trabalho diário, como analista, é enviar um e-mail para a diretoria, assim que começar a trabalhar, com o faturamento e a quantidade de produtos vendidos no dia anterior
#
# E-mail da diretoria: seugmail+diretoria@gmail.com<br>
# Local onde o sistema disponibiliza as vendas do dia anterior: https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing
#
# Para resolver isso, vamos usar o pyautogui, uma biblioteca de automação de comandos do mouse e do teclado

# %%
import http
import pyautogui
import time

# pyautogui.click -> clicar com o mouse
# pyautogui.write -> escrever um texto
# pyautogui.press -> pressionar uma tecla
# pyautogui.hotkey -> combinação de teclas

pyautogui.PAUSE = 1  # tempo de espera entre as ações

# Passo a passo do desafio de programação
# Objetivo: Criar um script Python que leia um arquivo de texto e conte a frequência de cada palavra nele.

# Passo 1: entrar o sistema da empresa (link do drive)
# abri o Chrome
pyautogui.press("win")
pyautogui.write("chrome")
pyautogui.press("enter")

time.sleep(2)  # esperar o Chrome abrir

# digitei o link do drive na barra de endereços
link = "https://drive.google.com/drive/folders"
pyautogui.write(link)
pyautogui.press("enter")
time.sleep(3)  # esperar o drive abrir

# %%
#Passo 2: navegar no sistema para encontrar a base de dados
pyautogui.click(x=2987, y=446, clicks=2)  # clicar na pasta correta (ajustar as coordenadas conforme necessário)
time.sleep(2)  # esperar a pasta abrir

#Passo 3: exportar a base de dados (baixar o arquivo)
pyautogui.click(x=2962, y=439)  # clicar no arquivo correto (ajustar as coordenadas conforme necessário)
pyautogui.click(x=3038, y=352)  # clicar no arquivo correto (ajustar as coordenadas conforme necessário)
pyautogui.click(x=2845, y=428)  # clicar no arquivo correto (ajustar as coordenadas conforme necessário)
time.sleep(1)

# %% [markdown]
# ### Vamos agora ler o arquivo baixado para pegar os indicadores
#
# - Faturamento
# - Quantidade de Produtos

# %%
import pandas

# Passo 4: Calcular os indicadores (faturamento e quantidade de produtos vendidos)
# abrir base de dados
caminho  = "C:\Users\ellen.salvador\Downloads\Vendas - Dez.xlsx"

# ver as informações da base de dados
# somar o faturamento de todos os produtos
# somar a quantidade de produtos

# %% [markdown]
# ### Vamos agora enviar um e-mail pelo gmail

# %% [markdown]
# #### Use esse código para descobrir qual a posição de um item que queira clicar
#
# - Lembre-se: a posição na sua tela é diferente da posição na minha tela

# %%
time.sleep(5)  # esperar o download completar
print(pyautogui.position())  # para descobrir a posição do mouse
# ou aperte ctrl + enter
# Out:
# Point(x=3213, y=23)
